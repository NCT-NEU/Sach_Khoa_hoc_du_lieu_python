# %% [markdown]
# # Thực hành: Nhập và lưu trữ dữ liệu

# %% [markdown]
# Một số công việc cần chuẩn bị trước khi làm bài tập thực hành:
#
#
# *   Các đoạn code bên dưới và bài tập thực hành được viết trên ngôn ngữ Python và sử dụng môi trường Colab của Google để thực thi.
# *   Lệnh **drive.mount('/content/drive')** giúp kết nối Google Drive với môi trường Colab, cho phép người dùng đọc và ghi dữ liệu giống như trên ổ đĩa cục bộ.
# *   Sau khi gắn kết thành công, toàn bộ nội dung Drive sẽ nằm trong thư mục **/content/drive/**, trong đó thư mục con phổ biến nhất là **/content/drive/MyDrive/** – nơi lưu trữ dữ liệu cá nhân của bạn. Việc khai báo biến **root_path = "/content/drive/MyDrive/"** giúp rút gọn đường dẫn, thuận tiện khi cần gọi tới các file nhiều lần trong chương trình.
# *   Tất cả file dữ liệu được sử dụng trong các bài thực hành bên dưới đều nằm trong thư mục tên là **data**. Cụ thể các file dữ liệu thực hành sẽ nằm trong thư mục **/content/drive/MyDrive/data/** trên *Google Drive* của bạn. Nếu *Google Drive* của bạn chưa có thư mục này, bạn cần tạo thư mục có tên **data** nằm trong thư mục **/content/drive/MyDrive/**, sau đó copy hoặc kéo thả toàn bộ các file dữ liệu vào đó.
# *   Các bạn hãy truy cập địa chỉ: https://github.com/tdminh2110-jpg/data_asean/blob/main/data.zip để tải file data.zip. Sau khi tải về, hãy giải nén file này, trong đó sẽ chứa toàn bộ các file dữ liệu cần thiết cho bài thực hành. Tiếp theo, các bạn nhớ sao chép toàn bộ các file này vào thư mục **/content/drive/MyDrive/data/** trong **Google Drive** để có thể sử dụng trong quá trình làm bài.

# %%
from google.colab import drive

#kết nối Google Drive với môi trường Colab
drive.mount('/content/drive')

#Hỗ trợ rút gọn đường dẫn, thuận tiện khi cần gọi tới các file nhiều lần trong chương trình.
root_path = "/content/drive/MyDrive/"
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## Phần 1: Đọc và lưu dữ liệu ở định dạng văn bản

# %% [markdown]
# ### Bài 1.1: Đọc file CSV và lấy 5 quốc gia có GDP cao nhất
#
# Đọc file **data/asean_gdp_2024.csv** chứa dữ liệu GDP của 10 nước ASEAN, sau đó hiển thị lên màn hình thông tin 5 quốc gia có GDP cao nhất.

# %%
import pandas as pd

# Đọc file CSV
# df =

# Sắp xếp giảm dần theo GDP và lấy 5 quốc gia đứng đầu
# top5 =

# print("5 quốc gia ASEAN có GDP cao nhất năm 2024:")
# print(top5)

# %% [markdown]
# ### Bài 1.2: Lấy 5 quốc gia có GDP thấp nhất
#
# Đọc file **data/asean_gdp_2024.csv** chứa dữ liệu GDP của 10 nước ASEAN, sau đó hiển thị lên màn hình thông tin 5 quốc gia có GDP thấp nhất.

# %%
# Đọc file CSV
df = pd.read_csv(root_path + "data/asean_gdp_2024.csv")

#...

# %% [markdown]
# ### Bài 1.3: Đổi tên cột sang Tiếng Việt
#
# Đọc file **data/asean_gdp_2024.csv** chứa dữ liệu GDP của 10 nước ASEAN, sau đó hiển thị lên màn hình thông tin với các cột đã được đổi tên sang Tiếng Việt. Lưu ý: Khi hiển thị thông tin, cần loại bỏ thông tin liên quan đến tiêu đề cột bằng Tiếng Anh.

# %%
# Lệnh đọc file và xác định tên cột bằng Tiếng Việt

# Loại bỏ thông tin liên quan đến tiêu đề cột bằng Tiếng Anh.

# %% [markdown]
# ### Bài 1.4: Đổi tên cột sang Tiếng Anh
#
# Đọc file **data/asean_growth_wide_2015_2024.csv** chứa dữ liệu tăng trưởng GDP của 10 nước ASEAN từ năm 2015 đến năm 2024, sau đó hiển thị lên màn hình thông tin với các cột đã được đổi tên sang Tiếng Anh.

# %%
# Lệnh đọc file và xác định tên cột bằng Tiếng Anh

# Loại bỏ thông tin liên quan đến tiêu đề cột bằng Tiếng Việt.

# %% [markdown]
# ### Bài 1.5: Đọc file Excel và thay giá trị thiếu bằng 0
#
# File dữ liệu dạng Excel **data/VN_Economic_Indicators_2024_with_missing.xlsx** chứa thông tin về một số chỉ số kinh tế của Việt Nam năm 2024. Tuy nhiên, file dữ liệu này có một số ô bị thiếu giá trị, hãy thay thế chúng bằng số 0 rồi hiển thị toàn bộ thông tin lên màn hình, sau đó đưa toàn bộ thông tin này ra file Excel khác.

# %%
# Đường dẫn file Excel

# Đọc dữ liệu từ sheet có tên "Vietnam 2024 Indicators"

# Thay thế toàn bộ giá trị NaN bằng 0 bằng cách sử dụng hàm fillna

# Hiển thị dữ liệu sau khi xử lý

# Lưu dữ liệu ra file Excel mới

# %% [markdown]
# ### Bài 1.6: Đọc dữ liệu CPI từ file Excel
#
# File dữ liệu dạng Excel **data/VN_Economic_Indicators_2024_full.xlsx** chứa thông tin về một số chỉ số kinh tế của Việt Nam năm 2024. Hãy đọc dữ liệu CPI từ file Excel này và hiển thị lên màn hình cột “Tháng” và cột “Chỉ số CPI”.

# %%
import pandas as pd

# Đọc file Excel

# Chọn hàng chứa CPI

# Bỏ cột "Chỉ số" vì chỉ lấy theo tháng

# Chuyển từ wide -> long: mỗi tháng thành 1 dòng

# Hiển thị kết quả

# %% [markdown]
# ### Bài 1.7: Đọc dữ liệu Thất nghiệp và PPI
#
# File dữ liệu dạng Excel **data/VN_Economic_Indicators_2024_full.xlsx** chứa thông tin về một số chỉ số kinh tế của Việt Nam năm 2024. Hãy đọc dữ liệu Thất nghiệp và PPI từ file Excel này và hiển thị lên màn hình cột “Tháng”, cột “Thất nghiệp” và cột “PPI”.

# %%
# Đường dẫn file Excel

# Lấy 2 dòng: Thất nghiệp và PPI

# Chuyển wide -> long

# Gộp 2 bảng theo cột "Tháng"

# Hiển thị kết quả

# %% [markdown]
# ### Bài 1.8: Gộp Thất nghiệp, PPI, CPI rồi ghi ra file Excel
#
# File dữ liệu dạng Excel **data/VN_Economic_Indicators_2024_full.xlsx** chứa thông tin về một số chỉ số kinh tế của Việt Nam năm 2024. Hãy đọc dữ liệu Thất nghiệp, PPI và CPI từ file Excel này, sau đó hiển thị lên màn hình cột “Tháng”, cột “Thất nghiệp”, cột “PPI” và cột “CPI”, cuối cùng đưa toàn bộ thông tin hiển thị ra một file Excel khác.

# %%
import pandas as pd

# Đọc file Excel gốc

# Tách từng chỉ số

# Chuyển wide -> long cho từng chỉ số

# Gộp các bảng lại theo cột "Tháng"

# Hiển thị dữ liệu

# Ghi dữ liệu ra file Excel mới

# %% [markdown]
# ### Bài 1.9: Đọc file JSON và chuyển thành DataFrame
#
# File dữ liệu JSON **data/vn10_stocks.json** chứa thông tin về chỉ số chứng khoán của một số cổ phiếu. Hãy đọc file JSON này rồi chuyển thành DataFrame.

# %%
import pandas as pd

# Đường dẫn tới file JSON

# Đọc file JSON và chuyển thành DataFrame

# Hiển thị toàn bộ thông tin

# %% [markdown]
# ## Phần 2: Thu thập dữ liệu web

# %% [markdown]
# ### Bài 2.1: Tải các bảng từ trang Wikipedia về ASEAN
#
# Hãy tải tất cả các bảng (table) từ địa chỉ Web **https://en.wikipedia.org/wiki/ASEAN**, sau đó in ra màn hình số lượng bảng đọc được từ Website này. Tiếp theo in ra màn hình nội dung của bảng số 6.

# %%
import pandas as pd
import requests
from io import StringIO

url = "https://en.wikipedia.org/wiki/ASEAN"
# Tạo header giả lập như trình duyệt thật
headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) "
                  "AppleWebKit/537.36 (KHTML, like Gecko) "
                  "Chrome/119.0.0.0 Safari/537.36"
}

# Dùng requests để tải HTML
response = requests.get(url, headers=headers)
response.raise_for_status()  # nếu lỗi HTTP sẽ báo ngay

# pandas.read_html tự động tải trang và parse tất cả các bảng HTML thành danh sách DataFrame
tables = pd.read_html(StringIO(response.text))

print(f"Số lượng bảng đọc được từ {url}: {len(tables)}\n")

# Lấy bảng số 6
df_table6 = tables[6]
print(df_table6)
# Out:
# /tmp/ipython-input-2288738358.py:18: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(response.text)
# Số lượng bảng đọc được từ https://en.wikipedia.org/wiki/ASEAN: 43
#
#                      Metropolitan area         Core city  Population  \
# 0                      Greater Jakarta           Jakarta    31673824
# 1                  Greater Manila Area            Manila    28250517
# 2   Ho Chi Minh City Metropolitan Area  Ho Chi Minh City    21281639
# 3                 Hanoi Capital Region             Hanoi    19980000
# 4          Bangkok Metropolitan Region           Bangkok    10696258
# 5                     Greater Surabaya          Surabaya     9924509
# 6                      Greater Bandung           Bandung     8790308
# 7                         Klang Valley      Kuala Lumpur     8455029
# ...

# %% [markdown]
# ### Bài 2.2: Loại bỏ cột thừa và đổi tên cột sang Tiếng Việt
#
# Loại bỏ cột Metropolitan area và cột Census year ở bảng 6 trong Bài 2.1. Sau đó đặt tên các cột còn lại bằng Tiếng Việt rồi hiển thị lên màn hình.

# %%
# Xoá các cột Metropolitan area và Census year

# Đổi tên cột sang Tiếng Việt

# Hiển thị kết quả

# %% [markdown]
# ### Bài 2.3: Năm thành phố đông dân nhất Đông Nam Á
#
# Dựa vào kết quả Bài 2.2, hãy in ra màn hình 5 thành phố có dân cư đông nhất ở Đông Nam Á.

# %%
# In lên màn hình 5 thành phố đông dân nhất Đông Nam Á

# %% [markdown]
# ### Bài 2.4: Vẽ biểu đồ tròn tỉ lệ dân số
#
# Vẽ biểu đồ tròn tỉ lệ dân số của Top-5 với phần còn lại.

# %%
import matplotlib.pyplot as plt

# Tính tổng dân số các thành phố top5

# Tính tổng dân số các thành phố còn lại

# Chuẩn bị dữ liệu cho biểu đồ tròn

# Vẽ biểu đồ tròn

# %% [markdown]
# ## Phần 3: Tương tác với API web

# %% [markdown]
# ### Bài 3.1: Lấy name, username và email của người dùng
#
# Lấy thông tin name, username và email của người dùng dựa trên địa chỉ **https://jsonplaceholder.typicode.com/users**, sau đó đưa vào DataFrame rồi hiển thị lên màn hình.

# %%
import requests
import pandas as pd

# Gửi request đến API

# Chuyển dữ liệu JSON thành DataFrame

# Hiển thị cột name, username, email

# %% [markdown]
# ### Bài 3.2: Lấy name, username, street và city của người dùng
#
# Lấy thông tin name, username, street và city của người dùng dựa trên địa chỉ **https://jsonplaceholder.typicode.com/users**, sau đó đưa vào DataFrame rồi hiển thị lên màn hình.

# %%
import requests
import pandas as pd

# Lấy dữ liệu từ API

# Chuyển thành list dict

# Trích xuất thông tin cần thiết

# Đưa vào DataFrame

# Hiển thị
